# %%
#Data preprocessing libraries
import pandas as pd
import numpy as np

# %%
# Importing dataset
cupData= pd.read_csv("data/ML-CUP20-TR.csv")

# %%
cupData
# Out:
#         SN        X1        X2        X3        X4        X5        X6  \
# 0        1 -1.227729  0.740105  0.453528 -0.761051 -0.537705  1.471803
# 1        2 -1.138424  0.401816  2.186819 -1.827160 -1.051730 -0.465455
# 2        3 -0.932510  1.226327  1.086944 -0.638613 -0.917756 -0.292441
# 3        4 -1.037358  1.370826  0.945194 -0.380548 -0.490811  0.370115
# 4        5  0.484440  0.192628 -0.348715  1.578780  0.485438 -0.340264
# ...    ...       ...       ...       ...       ...       ...       ...
# 1519  1520  0.938149 -2.146722 -1.284843  0.123335  0.573836 -0.535459
# 1520  1521  1.065179 -1.482392 -0.469370 -0.449872  0.260386  0.036954
# 1521  1522 -0.920735  0.130270  1.057556 -1.322965 -1.646272 -0.389996
# 1522  1523 -1.088826  1.850026  0.443968 -1.867511 -1.390189 -0.184824
# 1523  1524 -0.624057  1.270866  1.060025 -1.179048 -1.604488 -0.327172
#
#             X7        X8        X9       X10         Y1         Y2
# 0    -1.143195  2.034647  1.603978 -1.399807  58.616635 -36.878797
# 1    -1.186131  0.430193  1.344390 -0.886397  75.310457 -27.210492
# 2    -1.434838  0.461744  0.771817 -1.385428  68.513133 -31.582073
# 3    -0.312516  2.617978  1.347718 -0.583328  57.655634 -37.409493
# 4     0.189964 -0.240548 -0.701919  1.439752  43.327791 -35.763594
# ...        ...       ...       ...       ...        ...        ...
# 1519  0.720920 -1.364913 -0.971705  0.238846  28.914647  -7.531644
# 1520  1.226607 -0.919074 -1.486910  1.885093  34.994708 -23.832616
# 1521 -1.447411  0.335906  1.309321 -1.341631  72.885485 -28.704528
# 1522 -0.714050  1.857179  1.153889 -0.820186  62.954814 -34.902101
# 1523 -0.886385  1.067272  0.029235 -1.055179  60.144356 -36.302313
#
# [1524 rows x 13 columns]

# %%
# Dropping the first column of the dataset.
cupDataset = cupData.drop(['SN'],axis=1)
# Removing the first row

#counting the total number of rows and columns
cupDataset.shape
# Out:
# (1524, 12)

# %%
cupDataset

# %%
# More detailed information about the dataset
ml_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1524 entries, 0 to 1523
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1524 non-null   float64
#  1   X2      1524 non-null   float64
#  2   X3      1524 non-null   float64
#  3   X4      1524 non-null   float64
#  4   X5      1524 non-null   float64
#  5   X6      1524 non-null   float64
#  6   X7      1524 non-null   float64
#  7   X8      1524 non-null   float64
#  8   X9      1524 non-null   float64
#  9   X10     1524 non-null   float64
#  10  Y1      1524 non-null   float64
#  11  Y2      1524 non-null   float64
# dtypes: float64(12)
# memory usage: 143.0 KB

# %%
ml_dataset.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -1.227729  0.740105  0.453528 -0.761051 -0.537705  1.471803 -1.143195
# 1 -1.138424  0.401816  2.186819 -1.827160 -1.051730 -0.465455 -1.186131
# 2 -0.932510  1.226327  1.086944 -0.638613 -0.917756 -0.292441 -1.434838
# 3 -1.037358  1.370826  0.945194 -0.380548 -0.490811  0.370115 -0.312516
# 4  0.484440  0.192628 -0.348715  1.578780  0.485438 -0.340264  0.189964
#
#          X8        X9       X10         Y1         Y2
# 0  2.034647  1.603978 -1.399807  58.616635 -36.878797
# 1  0.430193  1.344390 -0.886397  75.310457 -27.210492
# 2  0.461744  0.771817 -1.385428  68.513133 -31.582073
# 3  2.617978  1.347718 -0.583328  57.655634 -37.409493
# 4 -0.240548 -0.701919  1.439752  43.327791 -35.763594

# %%
#Summery of numberica attributes
ml_dataset.describe()
# Out:
#                 X1           X2           X3           X4           X5  \
# count  1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean     -0.006309     0.020143     0.010106     0.003109     0.005619
# std       1.041026     1.045854     1.040690     1.048153     1.026938
# min      -2.247241    -2.158406    -2.068117    -3.190003    -2.657307
# 25%      -0.987447    -0.909239    -0.907696    -0.749282    -0.920508
# 50%       0.093405     0.062560    -0.023284    -0.030603     0.172423
# 75%       0.868999     0.894836     0.805138     0.695626     0.854577
# max       2.289184     2.623750     2.846079     2.803400     2.250039
#
#                 X6           X7           X8           X9          X10  \
# count  1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean      0.023872     0.006110    -0.011253     0.007343     0.005921
# std       1.054734     1.051558     1.045984     1.034932     1.057754
# min      -3.467126    -2.167943    -2.435643    -2.298636    -2.325151
# 25%      -0.658990    -0.983262    -0.893817    -0.939021    -0.972809
# 50%      -0.120652     0.136528    -0.005085     0.028914     0.208246
# 75%       0.701555     0.912320     0.783726     0.885435     0.829420
# max       2.800493     2.679499     2.617978     2.526212     2.393244
#
#                 Y1           Y2
# count  1524.000000  1524.000000
# mean     48.474973   -28.571117
# std      15.218671    10.269957
# min      25.978398   -41.864859
# 25%      34.666957   -36.935725
# 50%      45.333403   -30.642449
# 75%      61.544593   -22.860160
# max      78.836480    -4.064733

# %%
import matplotlib.pyplot as plt

# %%
ml_dataset.hist(bins=50, figsize=(30,25))
plt.show()

# %%
# Splitting dataSet to train and test data
test_set, train_set = trainT_split(ml_dataset, 0.2)
# displaying the train set rows
train_set.head()
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 644  -0.167434  0.552523 -0.483108  0.961061  0.462744  1.515526  0.152632
# 1410 -0.523822  1.235695  0.683345 -0.377827 -0.405829  1.623470 -1.093140
# 148   0.357515  1.005481  0.117576  2.083863  0.420846  0.461520  0.357871
# 226   0.513417 -0.184992 -0.959219  1.887002  0.228202  0.136462  0.448244
# 1168  0.984171 -0.686672 -1.314399 -0.346557  0.623798 -1.420536  1.112062
#
#             X8        X9       X10         Y1         Y2
# 644   0.438421  0.399242  0.196738  45.690459 -40.189421
# 1410  1.298191  1.133983 -0.548657  53.958102 -38.941363
# 148   0.547662 -0.189053  0.720189  45.897869 -40.485034
# 226  -1.303099 -0.409392  2.200148  42.118544 -32.755275
# 1168 -1.101173 -1.151119  0.464776  27.731950  -5.576452

# %%
# Spilitting the targets and input variables for the train set.
X_train = train_set.iloc[:,:-2]
y_train = train_set.iloc[:,[10,11]]
X_train.head()
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 644  -0.167434  0.552523 -0.483108  0.961061  0.462744  1.515526  0.152632
# 1410 -0.523822  1.235695  0.683345 -0.377827 -0.405829  1.623470 -1.093140
# 148   0.357515  1.005481  0.117576  2.083863  0.420846  0.461520  0.357871
# 226   0.513417 -0.184992 -0.959219  1.887002  0.228202  0.136462  0.448244
# 1168  0.984171 -0.686672 -1.314399 -0.346557  0.623798 -1.420536  1.112062
#
#             X8        X9       X10
# 644   0.438421  0.399242  0.196738
# 1410  1.298191  1.133983 -0.548657
# 148   0.547662 -0.189053  0.720189
# 226  -1.303099 -0.409392  2.200148
# 1168 -1.101173 -1.151119  0.464776

# %%
# Spilitting the targets and input variables for the test set.
X_test = test_set.iloc[:,:-2]
y_test = test_set.iloc[:,[10,11]]
y_test.head()
# Out:
#              Y1         Y2
# 659   53.812598 -39.178681
# 136   39.733447 -29.745940
# 1077  40.819086 -31.167366
# 936   32.221064 -17.434720
# 146   65.597966 -33.108092

# %%
# Defining our regressor 
max_depth = 30
regr_rf = RandomForestRegressor(n_estimators=100, max_depth=max_depth,random_state=2)
# Fitting our training data in out regressor
regr_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=30, random_state=2)

# %%
# Evaluating out model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model and collect the scores
n_scores = cross_val_score(regr_rf, X_test, y_test, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force the scores to be positive
n_scores = absolute(n_scores)
# summarize performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: 2.408 (0.411)

# %%
# This function Splits dataset to train and test set
# Parameters
#     - dataSet : Type: pandas DataFrame, Desc: The original dataset containg all the data.
#     - testRation : Type: float, Desc: Number between 0-1. indicating percentage of testRatio. Eg. 0.2, 20% of the
#                    dataSet will be assigned to testData and the rest 80% will be training data.
def trainT_split(dataSet, testRation):
    np.random.seed(15)
    shuffledData = np.random.permutation(len(dataSet))
    testsetSize = int(len(dataSet)*testRation)
    testData = shuffledData[:testsetSize]
    trainData = shuffledData[testsetSize:]
    return dataSet.iloc[testData], dataSet.iloc[trainData]

# %%
print(sklearn.__version__)
# Out:
# 0.23.2
