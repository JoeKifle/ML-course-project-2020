# %%
#importing libraries
import numpy as np
import pandas as pd
from datetime import datetime
import os
#keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split 
from keras.wrappers.scikit_learn import KerasClassifier

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow import keras
from datetime import datetime
from packaging import version
#################TRAINING PARAM
verbose_level=0

from tensorboard.plugins.hparams import api as hp

jobs=1

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import Dense, Input, Dropout
from keras import Sequential
from keras import regularizers
from keras.layers import Dropout

# for combining all the hyper-parameters
import itertools 
from time import time
from functools import reduce 
import operator

def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))


#jobs=1 #due to the low dimension of the dataset the single gpu version is slower, so I'm forcing it to the multi core version

# %%
g_decay = [0.01] # more estimations can be added


HP_BATCH_SIZE = hp.HParam('batch_size', hp.Discrete([10, 20, 40, 60, 80, 100]))
HP_NUM_UNITS1 = hp.HParam('num_units1', hp.Discrete([4,8,16, 32]))
HP_NUM_UNITS2 = hp.HParam('num_units2', hp.Discrete([4,8,16, 32]))
HP_ACTIVATION1 = hp.HParam('activation1', hp.Discrete(["relu", "tanh","sigmoid","softmax"]))
HP_ACTIVATION2 = hp.HParam('activation2', hp.Discrete(["relu", "tanh","sigmoid","softmax"]))
HP_ACTIVATION3 = hp.HParam('activation3', hp.Discrete(["relu", "tanh","sigmoid","softmax"]))
HP_INIT = hp.HParam('init_mode', hp.Discrete(['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']))
HP_MOMENTUM = hp.HParam('momentum', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
HP_LEARNING_RATE = hp.HParam('lr', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
HP_DROPOUT = hp.HParam('dropout', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
#HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
HP_EPOCH = hp.HParam('epoch', hp.IntInterval(50,250))
METRIC_ACCURACY = 'accuracy'


with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_BATCH_SIZE,HP_NUM_UNITS1,HP_NUM_UNITS2,HP_ACTIVATION1,HP_ACTIVATION2,HP_ACTIVATION3,HP_INIT,HP_MOMENTUM,HP_LEARNING_RATE, HP_DROPOUT, HP_EPOCH],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %%
# %load_ext tensorboard

# %%
# reading training and testing data from the csv file
trainDf = pd.read_csv ('data/csv/monks-3Train.csv',header=None).to_numpy()
testDf = pd.read_csv ('data/csv/monks-3Test.csv',header=None).to_numpy()
trainDf = minmax_scale(trainDf, feature_range=(0,1), axis=0)
testDf = minmax_scale(trainDf, feature_range=(0,1), axis=0)

# %%
#Preparing trainDf for training
trainX = trainDf[:, 1:7]
trainY = trainDf[:, 0]
#Preparing testDf for validation
testX = testDf[:, 1:7]
testY = testDf[:, 0]
#trainX = scaler.fit_transform(trainX)
#trainY = scaler.fit_transform(trainY)

# %%
import keras as ks
tensorboard_callback = ks.callbacks.TensorBoard(log_dir="./log",histogram_freq=1,write_graph=True,update_freq=1)

# %%
def create_model(lr=0.1,momentum=0.9,g_hiddeLayerunit1=4,g_hiddeLayerunit2=4,activation1="tanh",activation2="tanh",activation3="sigmoid",init_mode='uniform', g_decay=0.01):
    model = Sequential()
    model.add(Dense(g_hiddeLayerunit1, input_dim=6, kernel_initializer=init_mode, activation=activation1))
    model.add(Dropout(0.4)),
    model.add(Dense(g_hiddeLayerunit2, kernel_initializer=init_mode, activation=activation2,kernel_regularizer=regularizers.l1(0.01))) # l1 regularization parameter could also be something we can also grid search for.
    model.add(Dropout(0.4)),
    model.add(Dense(1, activation3))
    sgd = SGD(lr=lr, momentum=momentum, decay=g_decay, nesterov=False,)  # We can add decay to hyper parameter list to get optimum value. 
    model.compile(optimizer=sgd, loss='mean_squared_error',metrics=['accuracy'])
    return model

# %%
def train_test_model(hparams,tensorboard_callback):
    
    
  model = create_model(lr=hparams[HP_LEARNING_RATE],momentum=hparams[HP_MOMENTUM],g_hiddeLayerunit1=hparams[HP_NUM_UNITS1],g_hiddeLayerunit2=hparams[HP_NUM_UNITS1],activation1=hparams[HP_ACTIVATION1],activation2=hparams[HP_ACTIVATION2],activation3=hparams[HP_ACTIVATION3],init_mode=hparams[HP_INIT], g_decay=0.01)


  model.fit(trainX, trainY, epochs=hparams[HP_EPOCH], callbacks=[tensorboard_callback],verbose=0) # Run with 1 epoch to speed things up for demo purposes
  _, accuracy = model.evaluate(testX, testY)
  return accuracy

def run(run_dir,hparams,tensorboard_callback):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = train_test_model(hparams,tensorboard_callback)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

session_num = 0



for batch_size in HP_BATCH_SIZE.domain.values:
    for num_units1 in HP_NUM_UNITS1.domain.values:
      for num_units2 in HP_NUM_UNITS2.domain.values:
        for activation1 in HP_ACTIVATION1.domain.values:
          for activation2 in HP_ACTIVATION2.domain.values:
            for activation3 in HP_ACTIVATION3.domain.values:
              for init_mode in HP_INIT.domain.values:
                for momentum in HP_MOMENTUM.domain.values:
                  for lr in HP_LEARNING_RATE.domain.values:
                      for dropout_rate in HP_DROPOUT.domain.values:
                        #for optimizer in HP_OPTIMIZER.domain.values:
                            for epoch in range(HP_EPOCH.domain.min_value,HP_EPOCH.domain.max_value,50):
                              hparams = {
                                  HP_NUM_UNITS1: num_units1,
                                  HP_NUM_UNITS2: num_units2,
                                  HP_ACTIVATION1:activation1,
                                  HP_ACTIVATION2:activation2,
                                  HP_ACTIVATION3:activation3,
                                  HP_INIT:init_mode,
                                  HP_MOMENTUM:momentum,
                                  HP_LEARNING_RATE:lr,
                                  HP_DROPOUT: dropout_rate,
                                  #HP_OPTIMIZER: optimizer,
                                  HP_EPOCH:epoch,
                                  HP_BATCH_SIZE:batch_size,
                              }
                              run_name = "run-%d" % session_num
                              tensorboard_callback = ks.callbacks.TensorBoard(log_dir="logs/scalar/"+run_name,histogram_freq=1,write_graph=True,update_freq=1)
                              print('--- Starting trial: %s' % run_name)
                              print({h.name: hparams[h] for h in hparams})
                              run('logs/hparam_tuning/' + run_name, hparams,tensorboard_callback)
                              session_num += 1

# %tensorboard --logdir logs
# Out:
# --- Starting trial: run-0
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'glorot_normal', 'momentum': 0.1, 'lr': 0.1, 'dropout': 0.1, 'epoch': 50, 'batch_size': 10}
# Epoch 1/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6044 - accuracy: 0.4688WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5887 - accuracy: 0.4844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0580s). Check your callbacks.
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5647 - accuracy: 0.5082
# Epoch 2/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5640 - accuracy: 0.5082
# Epoch 3/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5634 - accuracy: 0.5082
# Epoch 4/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5627 - accuracy: 0.5082
# Epoch 5/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5621 - accuracy: 0.5082
# Epoch 6/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5615 - accuracy: 0.5082
# Epoch 7/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5609 - accuracy: 0.5082
# Epoch 8/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5604 - accuracy: 0.5082
# Epoch 9/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5598 - accuracy: 0.5082
# Epoch 10/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5593 - accuracy: 0.5082
# Epoch 11/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5588 - accuracy: 0.5082
# Epoch 12/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5583 - accuracy: 0.5082
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.5662 - accuracy: 0.50 - 0s 7ms/step - loss: 0.5578 - accuracy: 0.5082
# Epoch 14/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5574 - accuracy: 0.5082
# Epoch 15/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5538 - accuracy: 0.5082
# Epoch 16/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.5082
# Epoch 17/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4802 - accuracy: 0.5082
# Epoch 18/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4464 - accuracy: 0.5082
# Epoch 19/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.5082
# Epoch 20/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3935 - accuracy: 0.5082
# Epoch 21/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.5902
# Epoch 22/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3543 - accuracy: 0.5000
# Epoch 23/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3491 - accuracy: 0.5656
# Epoch 24/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3491 - accuracy: 0.5164
# Epoch 25/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3150 - accuracy: 0.5656
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.53 - 0s 5ms/step - loss: 0.3575 - accuracy: 0.5082
# Epoch 27/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3183 - accuracy: 0.5492
# Epoch 28/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3473 - accuracy: 0.5656
# Epoch 29/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3416 - accuracy: 0.5574
# Epoch 30/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3641 - accuracy: 0.4836
# Epoch 31/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3188 - accuracy: 0.5820
# Epoch 32/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.5410
# Epoch 33/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3404 - accuracy: 0.5328
# Epoch 34/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3606 - accuracy: 0.4754
# Epoch 35/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3316 - accuracy: 0.5246
# Epoch 36/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3281 - accuracy: 0.5328
# Epoch 37/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3415 - accuracy: 0.5410
# Epoch 38/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3060 - accuracy: 0.5574
# Epoch 39/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3238 - accuracy: 0.5246
# Epoch 40/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.6066
# Epoch 41/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3188 - accuracy: 0.5410
# Epoch 42/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3125 - accuracy: 0.5820
# Epoch 43/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.5246
# Epoch 44/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.5492
# Epoch 45/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3119 - accuracy: 0.5410
# Epoch 46/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2912 - accuracy: 0.5820
# Epoch 47/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3249 - accuracy: 0.5082
# Epoch 48/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3115 - accuracy: 0.5492
# Epoch 49/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3137 - accuracy: 0.4836
# Epoch 50/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2976 - accuracy: 0.5656
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3171 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2962 - accuracy: 0.6311
# --- Starting trial: run-1
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'glorot_normal', 'momentum': 0.1, 'lr': 0.1, 'dropout': 0.1, 'epoch': 100, 'batch_size': 10}
# Epoch 1/100
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7152 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5126s). Check your callbacks.
# 4/4 [==============================] - 1s 134ms/step - loss: 0.6009 - accuracy: 0.5246
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3857 - accuracy: 0.5738
# Epoch 3/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.5492
# Epoch 4/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3424 - accuracy: 0.5984
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3283 - accuracy: 0.5574
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3345 - accuracy: 0.5984
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3180 - accuracy: 0.6475
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3098 - accuracy: 0.5820
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3144 - accuracy: 0.5820
# Epoch 10/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3118 - accuracy: 0.5820
# Epoch 11/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3019 - accuracy: 0.6393
# Epoch 12/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2888 - accuracy: 0.5492
# Epoch 13/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2913 - accuracy: 0.6148
# Epoch 14/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2847 - accuracy: 0.6475
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2905 - accuracy: 0.6148
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2900 - accuracy: 0.5656
# Epoch 17/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2900 - accuracy: 0.6230
# Epoch 18/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.5574
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2877 - accuracy: 0.5820
# Epoch 20/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2948 - accuracy: 0.5820
# Epoch 21/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2883 - accuracy: 0.6475
# Epoch 22/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2826 - accuracy: 0.6230
# Epoch 23/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2929 - accuracy: 0.5492
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3011 - accuracy: 0.5656
# Epoch 25/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2724 - accuracy: 0.6803
# Epoch 26/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2649 - accuracy: 0.6393
# Epoch 27/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2829 - accuracy: 0.6066
# Epoch 28/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2729 - accuracy: 0.6230
# Epoch 29/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2914 - accuracy: 0.5902
# Epoch 30/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2913 - accuracy: 0.6475
# Epoch 31/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2792 - accuracy: 0.6557
# Epoch 32/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2760 - accuracy: 0.6967
# Epoch 33/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2639 - accuracy: 0.7049
# Epoch 34/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2954 - accuracy: 0.6066
# Epoch 35/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2902 - accuracy: 0.6066
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2832 - accuracy: 0.6311
# Epoch 37/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2894 - accuracy: 0.6475
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2811 - accuracy: 0.6557
# Epoch 39/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2725 - accuracy: 0.6393
# Epoch 40/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2709 - accuracy: 0.6557
# Epoch 41/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2893 - accuracy: 0.6148
# Epoch 42/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2617 - accuracy: 0.6885
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2836 - accuracy: 0.6393
# Epoch 44/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.6311
# Epoch 45/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2747 - accuracy: 0.6230
# Epoch 46/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2855 - accuracy: 0.5902
# Epoch 47/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.6639
# Epoch 48/100
# 4/4 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.53 - 0s 5ms/step - loss: 0.2739 - accuracy: 0.6311
# Epoch 49/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2652 - accuracy: 0.7049
# Epoch 50/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2897 - accuracy: 0.5738
# Epoch 51/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2660 - accuracy: 0.6885
# Epoch 52/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2720 - accuracy: 0.6967
# Epoch 53/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2743 - accuracy: 0.6475
# Epoch 54/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2590 - accuracy: 0.6885
# Epoch 55/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2960 - accuracy: 0.5656
# Epoch 56/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2846 - accuracy: 0.6148
# Epoch 57/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2696 - accuracy: 0.6885
# Epoch 58/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2648 - accuracy: 0.7049
# Epoch 59/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2729 - accuracy: 0.6639
# Epoch 60/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2891 - accuracy: 0.6393
# Epoch 61/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2841 - accuracy: 0.6148
# Epoch 62/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2920 - accuracy: 0.6803
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2689 - accuracy: 0.6639
# Epoch 64/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2631 - accuracy: 0.6639
# Epoch 65/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2578 - accuracy: 0.6967
# Epoch 66/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2658 - accuracy: 0.6885
# Epoch 67/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2661 - accuracy: 0.6721
# Epoch 68/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2757 - accuracy: 0.6475
# Epoch 69/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2545 - accuracy: 0.6967
# Epoch 70/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.6885
# Epoch 71/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2606 - accuracy: 0.7213
# Epoch 72/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2700 - accuracy: 0.7131
# Epoch 73/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2910 - accuracy: 0.6230
# Epoch 74/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2535 - accuracy: 0.7541
# Epoch 75/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2688 - accuracy: 0.7049
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2651 - accuracy: 0.6557
# Epoch 77/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2538 - accuracy: 0.6721
# Epoch 78/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2779 - accuracy: 0.6803
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.6557
# Epoch 80/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2623 - accuracy: 0.6885
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.6066
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2777 - accuracy: 0.5902
# Epoch 83/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2519 - accuracy: 0.7459
# Epoch 84/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2675 - accuracy: 0.6557
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2972 - accuracy: 0.5984
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2625 - accuracy: 0.6639
# Epoch 87/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2603 - accuracy: 0.6557
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.6885
# Epoch 89/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2454 - accuracy: 0.6885
# Epoch 90/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2678 - accuracy: 0.6721
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2559 - accuracy: 0.7213
# Epoch 92/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2574 - accuracy: 0.7213
# Epoch 93/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2736 - accuracy: 0.6393
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2531 - accuracy: 0.6885
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2777 - accuracy: 0.6393
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.5984
# Epoch 97/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2774 - accuracy: 0.5656
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2423 - accuracy: 0.7049
# Epoch 99/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2768 - accuracy: 0.6393
# Epoch 100/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2624 - accuracy: 0.6721
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2374 - accuracy: 0.8197
# --- Starting trial: run-2
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'glorot_normal', 'momentum': 0.1, 'lr': 0.1, 'dropout': 0.1, 'epoch': 150, 'batch_size': 10}
# Epoch 1/150
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5325 - accuracy: 0.5312WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.5140s). Check your callbacks.
# 4/4 [==============================] - 1s 134ms/step - loss: 0.5272 - accuracy: 0.5246
# Epoch 2/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5273 - accuracy: 0.5246
# Epoch 3/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5174 - accuracy: 0.5000
# Epoch 4/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3797 - accuracy: 0.5246
# Epoch 5/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3354 - accuracy: 0.5492
# Epoch 6/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3390 - accuracy: 0.4590
# Epoch 7/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3066 - accuracy: 0.4344
# Epoch 8/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2943 - accuracy: 0.5328
# Epoch 9/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.4508
# Epoch 10/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2878 - accuracy: 0.5492
# Epoch 11/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2786 - accuracy: 0.5738
# Epoch 12/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2901 - accuracy: 0.5574
# Epoch 13/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3042 - accuracy: 0.4262
# Epoch 14/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2904 - accuracy: 0.5000
# Epoch 15/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2740 - accuracy: 0.5492
# Epoch 16/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2791 - accuracy: 0.5738
# Epoch 17/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2837 - accuracy: 0.5082
# Epoch 18/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2776 - accuracy: 0.5082
# Epoch 19/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2711 - accuracy: 0.5738
# Epoch 20/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2991 - accuracy: 0.5246
# Epoch 21/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2775 - accuracy: 0.6311
# Epoch 22/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2802 - accuracy: 0.4754
# Epoch 23/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2879 - accuracy: 0.5574
# Epoch 24/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2737 - accuracy: 0.5164
# Epoch 25/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2861 - accuracy: 0.4672
# Epoch 26/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2761 - accuracy: 0.5902
# Epoch 27/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2654 - accuracy: 0.6393
# Epoch 28/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2773 - accuracy: 0.6230
# Epoch 29/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.5000
# Epoch 30/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2772 - accuracy: 0.5410
# Epoch 31/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2777 - accuracy: 0.5000
# Epoch 32/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2839 - accuracy: 0.5328
# Epoch 33/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2743 - accuracy: 0.5164
# Epoch 34/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2713 - accuracy: 0.5492
# Epoch 35/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2695 - accuracy: 0.5164
# Epoch 36/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.5492
# Epoch 37/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2730 - accuracy: 0.5328
# Epoch 38/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2757 - accuracy: 0.5328
# Epoch 39/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2845 - accuracy: 0.5164
# Epoch 40/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2741 - accuracy: 0.5492
# Epoch 41/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2712 - accuracy: 0.5246
# Epoch 42/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2739 - accuracy: 0.5246
# Epoch 43/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2779 - accuracy: 0.4836
# Epoch 44/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2679 - accuracy: 0.5984
# Epoch 45/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.4918
# Epoch 46/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2583 - accuracy: 0.5656
# Epoch 47/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2695 - accuracy: 0.5492
# Epoch 48/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2672 - accuracy: 0.5656
# Epoch 49/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2707 - accuracy: 0.5656
# Epoch 50/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2806 - accuracy: 0.5410
# Epoch 51/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2682 - accuracy: 0.5492
# Epoch 52/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2578 - accuracy: 0.6475
# Epoch 53/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2651 - accuracy: 0.6230
# Epoch 54/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2722 - accuracy: 0.4836
# Epoch 55/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2565 - accuracy: 0.5820
# Epoch 56/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2675 - accuracy: 0.5410
# Epoch 57/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2719 - accuracy: 0.5082
# Epoch 58/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2637 - accuracy: 0.5000
# Epoch 59/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2727 - accuracy: 0.4918
# Epoch 60/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2635 - accuracy: 0.5328
# Epoch 61/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2586 - accuracy: 0.5328
# Epoch 62/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.5492
# Epoch 63/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2582 - accuracy: 0.6066
# Epoch 64/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2611 - accuracy: 0.5410
# Epoch 65/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2661 - accuracy: 0.5656
# Epoch 66/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2677 - accuracy: 0.5164
# Epoch 67/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2590 - accuracy: 0.6066
# Epoch 68/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2675 - accuracy: 0.5328
# Epoch 69/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2668 - accuracy: 0.5164
# Epoch 70/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2575 - accuracy: 0.5492
# Epoch 71/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2664 - accuracy: 0.5164
# Epoch 72/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2646 - accuracy: 0.5246
# Epoch 73/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2621 - accuracy: 0.4836
# Epoch 74/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2626 - accuracy: 0.5492
# Epoch 75/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2549 - accuracy: 0.6066
# Epoch 76/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2530 - accuracy: 0.5820
# Epoch 77/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2560 - accuracy: 0.5328
# Epoch 78/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2663 - accuracy: 0.4836
# Epoch 79/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2588 - accuracy: 0.6148
# Epoch 80/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2488 - accuracy: 0.6475
# Epoch 81/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2543 - accuracy: 0.5984
# Epoch 82/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2543 - accuracy: 0.5902
# Epoch 83/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2581 - accuracy: 0.5984
# Epoch 84/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2451 - accuracy: 0.6311
# Epoch 85/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2721 - accuracy: 0.5656
# Epoch 86/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2630 - accuracy: 0.6311
# Epoch 87/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2525 - accuracy: 0.6066
# Epoch 88/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2619 - accuracy: 0.5492
# Epoch 89/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2483 - accuracy: 0.6475
# Epoch 90/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2652 - accuracy: 0.5082
# Epoch 91/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2620 - accuracy: 0.5492
# Epoch 92/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2558 - accuracy: 0.5984
# Epoch 93/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2744 - accuracy: 0.4836
# Epoch 94/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2580 - accuracy: 0.5328
# Epoch 95/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2548 - accuracy: 0.5738
# Epoch 96/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2649 - accuracy: 0.4590
# Epoch 97/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2596 - accuracy: 0.5574
# Epoch 98/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2532 - accuracy: 0.5328
# Epoch 99/150
# 4/4 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.71 - 0s 5ms/step - loss: 0.2457 - accuracy: 0.6230
# Epoch 100/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2581 - accuracy: 0.6066
# Epoch 101/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2574 - accuracy: 0.5410
# Epoch 102/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2602 - accuracy: 0.5574
# Epoch 103/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2385 - accuracy: 0.6311
# Epoch 104/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.5656
# Epoch 105/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2598 - accuracy: 0.4754
# Epoch 106/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2631 - accuracy: 0.5246
# Epoch 107/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2603 - accuracy: 0.5492
# Epoch 108/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2653 - accuracy: 0.5410
# Epoch 109/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2594 - accuracy: 0.5574
# Epoch 110/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2578 - accuracy: 0.5492
# Epoch 111/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2534 - accuracy: 0.5656
# Epoch 112/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2548 - accuracy: 0.5656
# Epoch 113/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2545 - accuracy: 0.5574
# Epoch 114/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2585 - accuracy: 0.5082
# Epoch 115/150
# 4/4 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.56 - 0s 5ms/step - loss: 0.2522 - accuracy: 0.5820
# Epoch 116/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2756 - accuracy: 0.4672
# Epoch 117/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.5820
# Epoch 118/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2478 - accuracy: 0.5656
# Epoch 119/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2499 - accuracy: 0.4836
# Epoch 120/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2708 - accuracy: 0.4836
# Epoch 121/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2508 - accuracy: 0.6066
# Epoch 122/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2586 - accuracy: 0.5328
# Epoch 123/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2596 - accuracy: 0.5246
# Epoch 124/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2422 - accuracy: 0.6148
# Epoch 125/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.5082
# Epoch 126/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2575 - accuracy: 0.5246
# Epoch 127/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2379 - accuracy: 0.6393
# Epoch 128/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2478 - accuracy: 0.5902
# Epoch 129/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2454 - accuracy: 0.5820
# Epoch 130/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2576 - accuracy: 0.5492
# Epoch 131/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2447 - accuracy: 0.5492
# Epoch 132/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2399 - accuracy: 0.6393
# Epoch 133/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2565 - accuracy: 0.5574
# Epoch 134/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2518 - accuracy: 0.5328
# Epoch 135/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2430 - accuracy: 0.5984
# Epoch 136/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2425 - accuracy: 0.6393
# Epoch 137/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2450 - accuracy: 0.5656
# Epoch 138/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.6066
# Epoch 139/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2314 - accuracy: 0.6475
# Epoch 140/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2610 - accuracy: 0.5410
# Epoch 141/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2429 - accuracy: 0.6393
# Epoch 142/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2600 - accuracy: 0.5984
# Epoch 143/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2545 - accuracy: 0.5492
# Epoch 144/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2425 - accuracy: 0.6311
# Epoch 145/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2740 - accuracy: 0.5738
# Epoch 146/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2497 - accuracy: 0.6148
# Epoch 147/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2502 - accuracy: 0.6311
# Epoch 148/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2490 - accuracy: 0.5820
# Epoch 149/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2594 - accuracy: 0.5738
# Epoch 150/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2388 - accuracy: 0.6803
# 4/4 [==============================] - 0s 752us/step - loss: 0.2386 - accuracy: 0.7459
# --- Starting trial: run-3
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'glorot_normal', 'momentum': 0.1, 'lr': 0.1, 'dropout': 0.1, 'epoch': 200, 'batch_size': 10}
# Epoch 1/200
# 2/4 [==============>...............] - ETA: 0s - loss: 0.4775 - accuracy: 0.5781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4700s). Check your callbacks.
# 4/4 [==============================] - 0s 122ms/step - loss: 0.5064 - accuracy: 0.5164
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3818 - accuracy: 0.5164
# Epoch 3/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3430 - accuracy: 0.5738
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3084 - accuracy: 0.6148
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3003 - accuracy: 0.6230
# Epoch 6/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3220 - accuracy: 0.5656
# Epoch 7/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.5984
# Epoch 8/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2956 - accuracy: 0.5820
# Epoch 9/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3045 - accuracy: 0.5984
# Epoch 10/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.5984
# Epoch 11/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.6148
# Epoch 12/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2901 - accuracy: 0.5738
# Epoch 13/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2774 - accuracy: 0.6230
# Epoch 14/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3062 - accuracy: 0.5246
# Epoch 15/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2776 - accuracy: 0.6311
# Epoch 16/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2798 - accuracy: 0.6393
# Epoch 17/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2937 - accuracy: 0.5984
# Epoch 18/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2630 - accuracy: 0.6475
# Epoch 19/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2768 - accuracy: 0.6148
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2581 - accuracy: 0.6967
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2997 - accuracy: 0.6066
# Epoch 22/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2839 - accuracy: 0.5902
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2988 - accuracy: 0.5574
# Epoch 24/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2763 - accuracy: 0.6557
# Epoch 25/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2577 - accuracy: 0.7377
# Epoch 26/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2691 - accuracy: 0.6803
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2538 - accuracy: 0.6639
# Epoch 28/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2688 - accuracy: 0.6148
# Epoch 29/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2560 - accuracy: 0.6557
# Epoch 30/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.5328
# Epoch 31/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2657 - accuracy: 0.6475
# Epoch 32/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2831 - accuracy: 0.5820
# Epoch 33/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2859 - accuracy: 0.5820
# Epoch 34/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2681 - accuracy: 0.6475
# Epoch 35/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2716 - accuracy: 0.6230
# Epoch 36/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2757 - accuracy: 0.6393
# Epoch 37/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2776 - accuracy: 0.6230
# Epoch 38/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2715 - accuracy: 0.6393
# Epoch 39/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2858 - accuracy: 0.6148
# Epoch 40/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2660 - accuracy: 0.6311
# Epoch 41/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2778 - accuracy: 0.5574
# Epoch 42/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.6311
# Epoch 43/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2609 - accuracy: 0.6803
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2528 - accuracy: 0.7049
# Epoch 45/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2529 - accuracy: 0.6803
# Epoch 46/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2636 - accuracy: 0.6475
# Epoch 47/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2667 - accuracy: 0.6803
# Epoch 48/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2549 - accuracy: 0.6475
# Epoch 49/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2615 - accuracy: 0.6393
# Epoch 50/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2723 - accuracy: 0.6230
# Epoch 51/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2652 - accuracy: 0.6557
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2459 - accuracy: 0.6967
# Epoch 53/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2540 - accuracy: 0.7049
# Epoch 54/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2680 - accuracy: 0.6803
# Epoch 55/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.6311
# Epoch 56/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2575 - accuracy: 0.6803
# Epoch 57/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2613 - accuracy: 0.6639
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.6311
# Epoch 59/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2522 - accuracy: 0.6803
# Epoch 60/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2566 - accuracy: 0.6475
# Epoch 61/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2482 - accuracy: 0.6393
# Epoch 62/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.5820
# Epoch 63/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2605 - accuracy: 0.6639
# Epoch 64/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2387 - accuracy: 0.7049
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2614 - accuracy: 0.6311
# Epoch 66/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2773 - accuracy: 0.5902
# Epoch 67/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2722 - accuracy: 0.5984
# Epoch 68/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2583 - accuracy: 0.6475
# Epoch 69/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2643 - accuracy: 0.6393
# Epoch 70/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.5902
# Epoch 71/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2571 - accuracy: 0.6639
# Epoch 72/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2613 - accuracy: 0.6311
# Epoch 73/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2592 - accuracy: 0.6475
# Epoch 74/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2514 - accuracy: 0.6885
# Epoch 75/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2718 - accuracy: 0.6393
# Epoch 76/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2672 - accuracy: 0.6557
# Epoch 77/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.5738
# Epoch 78/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2417 - accuracy: 0.7049
# Epoch 79/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2628 - accuracy: 0.6475
# Epoch 80/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2653 - accuracy: 0.6639
# Epoch 81/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2550 - accuracy: 0.6393
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2739 - accuracy: 0.6066
# Epoch 83/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2416 - accuracy: 0.6885
# Epoch 84/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2740 - accuracy: 0.6148
# Epoch 85/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2519 - accuracy: 0.6803
# Epoch 86/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2704 - accuracy: 0.6148
# Epoch 87/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2432 - accuracy: 0.6885
# Epoch 88/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2618 - accuracy: 0.6230
# Epoch 89/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2612 - accuracy: 0.6148
# Epoch 90/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2483 - accuracy: 0.6311
# Epoch 91/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2583 - accuracy: 0.6721
# Epoch 92/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2763 - accuracy: 0.5984
# Epoch 93/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2480 - accuracy: 0.6967
# Epoch 94/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2655 - accuracy: 0.5902
# Epoch 95/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2480 - accuracy: 0.6557
# Epoch 96/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2563 - accuracy: 0.6557
# Epoch 97/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2412 - accuracy: 0.6639
# Epoch 98/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2352 - accuracy: 0.7213
# Epoch 99/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2563 - accuracy: 0.6557
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.6393
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2458 - accuracy: 0.7049
# Epoch 102/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2334 - accuracy: 0.6967
# Epoch 103/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2337 - accuracy: 0.6639
# Epoch 104/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.6557
# Epoch 105/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.7541
# Epoch 106/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2414 - accuracy: 0.7049
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2599 - accuracy: 0.5984
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2500 - accuracy: 0.6148
# Epoch 109/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2774 - accuracy: 0.6066
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2786 - accuracy: 0.5902
# Epoch 111/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2609 - accuracy: 0.5902
# Epoch 112/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2450 - accuracy: 0.7131
# Epoch 113/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2569 - accuracy: 0.6557
# Epoch 114/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2535 - accuracy: 0.6721
# Epoch 115/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2328 - accuracy: 0.6885
# Epoch 116/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2581 - accuracy: 0.6230
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2402 - accuracy: 0.6803
# Epoch 118/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2625 - accuracy: 0.6148
# Epoch 119/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2520 - accuracy: 0.6639
# Epoch 120/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2608 - accuracy: 0.6393
# Epoch 121/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2510 - accuracy: 0.6475
# Epoch 122/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2323 - accuracy: 0.6885
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.6475
# Epoch 124/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2596 - accuracy: 0.6639
# Epoch 125/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2558 - accuracy: 0.6721
# Epoch 126/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.6557
# Epoch 127/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2621 - accuracy: 0.6148
# Epoch 128/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2381 - accuracy: 0.6721
# Epoch 129/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2591 - accuracy: 0.5738
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2448 - accuracy: 0.6393
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2247 - accuracy: 0.7213
# Epoch 132/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2488 - accuracy: 0.6721
# Epoch 133/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2546 - accuracy: 0.6721
# Epoch 134/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2517 - accuracy: 0.6393
# Epoch 135/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.6967
# Epoch 136/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2448 - accuracy: 0.6557
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2397 - accuracy: 0.6803
# Epoch 138/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2488 - accuracy: 0.6557
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.7131
# Epoch 140/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.6803
# Epoch 141/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2349 - accuracy: 0.7213
# Epoch 142/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2483 - accuracy: 0.6639
# Epoch 143/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2512 - accuracy: 0.6557
# Epoch 144/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2465 - accuracy: 0.7049
# Epoch 145/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2540 - accuracy: 0.6557
# Epoch 146/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2386 - accuracy: 0.6803
# Epoch 147/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2343 - accuracy: 0.6967
# Epoch 148/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2403 - accuracy: 0.6639
# Epoch 149/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.6721
# Epoch 150/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2456 - accuracy: 0.6393
# Epoch 151/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.6803
# Epoch 152/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.6803
# Epoch 153/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2331 - accuracy: 0.6967
# Epoch 154/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2531 - accuracy: 0.6393
# Epoch 155/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2414 - accuracy: 0.6803
# Epoch 156/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2507 - accuracy: 0.6803
# Epoch 157/200
# ...
# Epoch 79/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2842 - accuracy: 0.6230
# Epoch 80/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2803 - accuracy: 0.6066
# Epoch 81/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2895 - accuracy: 0.6311
# Epoch 82/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2729 - accuracy: 0.6557
# Epoch 83/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2755 - accuracy: 0.6066
# Epoch 84/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.5902
# Epoch 85/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.5656
# Epoch 86/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2797 - accuracy: 0.6230
# Epoch 87/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3041 - accuracy: 0.5738
# Epoch 88/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2948 - accuracy: 0.5820
# Epoch 89/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.6230
# Epoch 90/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2854 - accuracy: 0.5902
# Epoch 91/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2669 - accuracy: 0.6475
# Epoch 92/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2724 - accuracy: 0.6967
# Epoch 93/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2876 - accuracy: 0.6066
# Epoch 94/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.5984
# Epoch 95/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.6885
# Epoch 96/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2781 - accuracy: 0.6148
# Epoch 97/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.6311
# Epoch 98/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2829 - accuracy: 0.5820
# Epoch 99/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2777 - accuracy: 0.6230
# Epoch 100/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2850 - accuracy: 0.6148
# Epoch 101/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2904 - accuracy: 0.5902
# Epoch 102/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2749 - accuracy: 0.5902
# Epoch 103/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2785 - accuracy: 0.6148
# Epoch 104/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2926 - accuracy: 0.5984
# Epoch 105/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2823 - accuracy: 0.6475
# Epoch 106/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2736 - accuracy: 0.6066
# Epoch 107/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2751 - accuracy: 0.6311
# Epoch 108/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2778 - accuracy: 0.6557
# Epoch 109/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2975 - accuracy: 0.5738
# Epoch 110/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2779 - accuracy: 0.6475
# Epoch 111/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.5984
# Epoch 112/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2851 - accuracy: 0.5492
# Epoch 113/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2827 - accuracy: 0.6230
# Epoch 114/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2827 - accuracy: 0.6311
# Epoch 115/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2847 - accuracy: 0.5738
# Epoch 116/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2652 - accuracy: 0.6393
# Epoch 117/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2853 - accuracy: 0.5984
# Epoch 118/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.5738
# Epoch 119/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2718 - accuracy: 0.6475
# Epoch 120/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2883 - accuracy: 0.5820
# Epoch 121/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2662 - accuracy: 0.6803
# Epoch 122/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2880 - accuracy: 0.5820
# Epoch 123/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2740 - accuracy: 0.6230
# Epoch 124/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2819 - accuracy: 0.6311
# Epoch 125/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2951 - accuracy: 0.5574
# Epoch 126/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2821 - accuracy: 0.6475
# Epoch 127/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.6311
# Epoch 128/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2836 - accuracy: 0.5902
# Epoch 129/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.6967
# Epoch 130/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2845 - accuracy: 0.6066
# Epoch 131/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2832 - accuracy: 0.6311
# Epoch 132/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2719 - accuracy: 0.6803
# Epoch 133/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2923 - accuracy: 0.5738
# Epoch 134/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2893 - accuracy: 0.5656
# Epoch 135/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2828 - accuracy: 0.5738
# Epoch 136/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2622 - accuracy: 0.6639
# Epoch 137/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2743 - accuracy: 0.6557
# Epoch 138/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2821 - accuracy: 0.5492
# Epoch 139/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2632 - accuracy: 0.6803
# Epoch 140/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2860 - accuracy: 0.5738
# Epoch 141/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2796 - accuracy: 0.6230
# Epoch 142/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2788 - accuracy: 0.6230
# Epoch 143/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2779 - accuracy: 0.6721
# Epoch 144/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2810 - accuracy: 0.6148
# Epoch 145/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2823 - accuracy: 0.5902
# Epoch 146/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.5738
# Epoch 147/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2769 - accuracy: 0.5902
# Epoch 148/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.6148
# Epoch 149/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2700 - accuracy: 0.6721
# Epoch 150/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.6557
# 4/4 [==============================] - 0s 750us/step - loss: 0.2643 - accuracy: 0.7131
# --- Starting trial: run-27
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'glorot_normal', 'momentum': 0.1, 'lr': 0.1, 'dropout': 0.7000000000000001, 'epoch': 200, 'batch_size': 10}
# Epoch 1/200
# 2/4 [==============>...............] - ETA: 0s - loss: 0.4975 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4880s). Check your callbacks.
# 4/4 [==============================] - 1s 128ms/step - loss: 0.5516 - accuracy: 0.5082
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5510 - accuracy: 0.5082
# Epoch 3/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5503 - accuracy: 0.5082
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5492 - accuracy: 0.5082
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4898 - accuracy: 0.5082
# Epoch 6/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3860 - accuracy: 0.5082
# Epoch 7/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3429 - accuracy: 0.5082
# Epoch 8/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3155 - accuracy: 0.4672
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.4918
# Epoch 10/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3075 - accuracy: 0.5082
# Epoch 11/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3092 - accuracy: 0.4836
# Epoch 12/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.4918
# Epoch 13/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3063 - accuracy: 0.4590
# Epoch 14/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3083 - accuracy: 0.4754
# Epoch 15/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3039 - accuracy: 0.4918
# Epoch 16/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3057 - accuracy: 0.4672
# Epoch 17/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3029 - accuracy: 0.5246
# Epoch 18/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3019 - accuracy: 0.4754
# Epoch 19/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2968 - accuracy: 0.5574
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.4754
# Epoch 21/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2969 - accuracy: 0.5000
# Epoch 22/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3008 - accuracy: 0.5328
# Epoch 23/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2985 - accuracy: 0.5082
# Epoch 24/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3036 - accuracy: 0.4262
# Epoch 25/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.5574
# Epoch 26/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2958 - accuracy: 0.5082
# Epoch 27/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.4836
# Epoch 28/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3022 - accuracy: 0.4180
# Epoch 29/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2964 - accuracy: 0.4672
# Epoch 30/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2969 - accuracy: 0.5082
# Epoch 31/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2980 - accuracy: 0.4754
# Epoch 32/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2973 - accuracy: 0.4344
# Epoch 33/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2930 - accuracy: 0.4672
# Epoch 34/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2947 - accuracy: 0.4836
# Epoch 35/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2943 - accuracy: 0.4836
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2943 - accuracy: 0.4836
# Epoch 37/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.4672
# Epoch 38/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.4918
# Epoch 39/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2935 - accuracy: 0.4836
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2932 - accuracy: 0.4836
# Epoch 41/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2885 - accuracy: 0.5938
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-13629f11e85a> in <module>
#      49                               print('--- Starting trial: %s' % run_name)
#      50                               print({h.name: hparams[h] for h in hparams})
# ---> 51                               run('logs/hparam_tuning/' + run_name, hparams,tensorboard_callback)
#      52                               session_num += 1
#      53
#
# <ipython-input-11-13629f11e85a> in run(run_dir, hparams, tensorboard_callback)
#      12   with tf.summary.create_file_writer(run_dir).as_default():
#      13     hp.hparams(hparams)  # record the values used in this trial
# ---> 14     accuracy = train_test_model(hparams,tensorboard_callback)
#      15     tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)
#      16
#
# <ipython-input-11-13629f11e85a> in train_test_model(hparams, tensorboard_callback)
#       5
#       6
# ----> 7   model.fit(trainX, trainY, epochs=hparams[HP_EPOCH], callbacks=[tensorboard_callback]) # Run with 1 epoch to speed things up for demo purposes
#       8   _, accuracy = model.evaluate(testX, testY)
#       9   return accuracy
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1135           epoch_logs.update(val_logs)
#    1136
# -> 1137         callbacks.on_epoch_end(epoch, epoch_logs)
#    1138         training_logs = epoch_logs
#    1139         if self.stop_training:
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     410     for callback in self.callbacks:
#     411       if getattr(callback, '_supports_tf_logs', False):
# --> 412         callback.on_epoch_end(epoch, logs)
#     413       else:
#     414         if numpy_logs is None:  # Only convert once.
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#    2180
#    2181     if self.histogram_freq and epoch % self.histogram_freq == 0:
# -> 2182       self._log_weights(epoch)
#    2183
#    2184     if self.embeddings_freq and epoch % self.embeddings_freq == 0:
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\keras\callbacks.py in _log_weights(self, epoch)
#    2235             if self.write_images:
#    2236               self._log_weight_as_image(weight, weight_name, epoch)
# -> 2237         self._train_writer.flush()
#    2238
#    2239   def _log_weight_as_image(self, weight, weight_name, epoch):
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in flush(self)
#     284     if self._v2 and context.executing_eagerly() and self._closed:
#     285       return
# --> 286     return _flush_fn(writer=self)
#     287
#     288   def close(self):
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in flush(writer, name)
#     965     resource = writer
#     966   with ops.device("cpu:0"):
# --> 967     return gen_summary_ops.flush_summary_writer(resource, name=name)
#     968
#     969
#
# C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\ops\gen_summary_ops.py in flush_summary_writer(writer, name)
#     195       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     196         _ctx._context_handle, tld.device_name, "FlushSummaryWriter", name,
# --> 197         tld.op_callbacks, writer)
#     198       return _result
#     199     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [raw]
# %%time
# def create_model(lr=0.1,momentum=0.9,g_hiddeLayerunit1=4,g_hiddeLayerunit2=4,activation1="tanh",activation2="tanh",activation3="sigmoid",init_mode='uniform', g_decay=0.01):
#     model = Sequential()
#     model.add(Dense(g_hiddeLayerunit1, input_dim=6, kernel_initializer=init_mode, activation=activation1))
#     model.add(Dropout(0.4)),
#     model.add(Dense(g_hiddeLayerunit2, kernel_initializer=init_mode, activation=activation2,kernel_regularizer=regularizers.l1(0.01))) # l1 regularization parameter could also be something we can also grid search for.
#     model.add(Dropout(0.4)),
#     model.add(Dense(1, activation3))
#     sgd = SGD(lr=lr, momentum=momentum, decay=g_decay, nesterov=False,)  # We can add decay to hyper parameter list to get optimum value.
#     model.compile(optimizer=sgd, loss='mean_squared_error',metrics=['accuracy'])
#     return model
#
#
# class KerasRegressorTB(KerasClassifier):
#
#     def __init__(self, *args, **kwargs):
#         super(KerasClassifier, self).__init__(*args, **kwargs)
#
#     def fit(self, x, y, log_dir=None, **kwargs):
#         cbs = None
#         if log_dir is not None:
#             # Make sure the base log directory exists
#             try:
#                 os.makedirs(log_dir)
#             except OSError:
#                 pass
#             params = self.get_params()
#             conf = ",".join("{}={}".format(k, params[k])
#                             for k in sorted(params))
#             conf_dir_base = os.path.join(log_dir, conf)
#             # Find a new directory to place the logs
#             for i in itertools.count():
#                 try:
#                     conf_dir = "{}_split-{}".format(conf_dir_base, i)
#                     os.makedirs(conf_dir)
#                     break
#                 except OSError:
#                     pass
#             cbs = [ks.callbacks.TensorBoard(log_dir=conf_dir, histogram_freq=0,
#                                write_graph=True, write_images=False)]
#         super(KerasRegressorTB, self).fit(x, y, callbacks=cbs, **kwargs)
#
#
#
# # define the grid search parameters
# batch_size = [10, 20, 40, 60, 80, 100]
# epochs = [10, 50, 100]
# g_hiddeLayerunit1=[4,8,16]
# g_hiddeLayerunit2=[4,8,16]
# g_decay = [0.01] # more estimations can be added
# activation1 = ["relu", "tanh","sigmoid","softmax"]
# activation2 = ["relu", "tanh","sigmoid","softmax"]
# activation3 = ["relu", "tanh","sigmoid","softmax"]
# init_mode = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']
# lr=np.arange(0.1, 0.9, 0.1).tolist()
# momentum=np.arange(0.1, 0.9, 0.1).tolist()
# param_grid = dict(
#     lr=lr,
#    # g_hiddeLayerunit1=g_hiddeLayerunit1,
#    # g_hiddeLayerunit2=g_hiddeLayerunit2,
#    # activation1=activation1,
#    # activation2=activation2,
#    # activation3=activation3,
#    # batch_size=batch_size,
#    # init_mode=init_mode,
#    # g_decay = g_decay,
#    # epochs=epochs
#     )
# model = KerasRegressorTB(build_fn=create_model)
# print("HE")
#
#
# print("HEHE")
# start_time = timer(None) # timing starts from this point for "start_time" variable
# grid = GridSearchCV(estimator=model, param_grid=param_grid,fit_params={'log_dir': './Graph'},n_jobs=1,cv=3,verbose=verbose_level)
#
#
# print("HEHEHE")
# grid_result = grid.fit(trainX, trainY)
# timer(start_time) # timing ends here for "start_time" variable
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# print("Mean\tSTD\tParams")
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs
