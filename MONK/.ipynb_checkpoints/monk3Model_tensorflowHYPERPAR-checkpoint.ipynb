# %%
#importing libraries
import numpy as np
import pandas as pd
from datetime import datetime
import os
#keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split 
from keras.wrappers.scikit_learn import KerasClassifier

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow import keras
from datetime import datetime
from packaging import version
#################TRAINING PARAM
verbose_level=0

from tensorboard.plugins.hparams import api as hp

jobs=1

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import Dense, Input, Dropout
from keras import Sequential
from keras import regularizers
from keras.layers import Dropout

# for combining all the hyper-parameters
import itertools 
from time import time
from functools import reduce 
import operator

def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))


#jobs=1 #due to the low dimension of the dataset the single gpu version is slower, so I'm forcing it to the multi core version

# %%
g_decay = [0.01] # more estimations can be added





# HP_BATCH_SIZE = hp.HParam('batch_size', hp.Discrete([10, 20, 40, 60, 80, 100]))
# HP_NUM_UNITS1 = hp.HParam('num_units1', hp.Discrete([4,8,16, 32]))
# HP_NUM_UNITS2 = hp.HParam('num_units2', hp.Discrete([4,8,16, 32]))
# HP_ACTIVATION1 = hp.HParam('activation1', hp.Discrete(["relu", "tanh","sigmoid","softmax"]))
# HP_ACTIVATION2 = hp.HParam('activation2', hp.Discrete(["relu", "tanh","sigmoid","softmax"]))
# HP_ACTIVATION3 = hp.HParam('activation3', hp.Discrete(["relu", "tanh","sigmoid","softmax"]))
# HP_INIT = hp.HParam('init_mode', hp.Discrete(['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']))
# HP_MOMENTUM = hp.HParam('momentum', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
# HP_LEARNING_RATE = hp.HParam('lr', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
# HP_DROPOUT1 = hp.HParam('dropout1', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
# HP_DROPOUT2 = hp.HParam('dropout2', hp.Discrete(np.arange(0.1, 0.9, 0.1).tolist()))
# #HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# HP_EPOCH = hp.HParam('epoch',hp.Discrete(range(50,250,50)))


HP_BATCH_SIZE = hp.HParam('batch_size', hp.Discrete([50]))
HP_NUM_UNITS1 = hp.HParam('num_units1', hp.Discrete([4,8]))
HP_NUM_UNITS2 = hp.HParam('num_units2', hp.Discrete([4,8]))
HP_ACTIVATION1 = hp.HParam('activation1', hp.Discrete(["relu", "tanh"]))
HP_ACTIVATION2 = hp.HParam('activation2', hp.Discrete(["relu", "tanh"]))
HP_ACTIVATION3 = hp.HParam('activation3', hp.Discrete(["relu", "tanh"]))
HP_INIT = hp.HParam('init_mode', hp.Discrete(['uniform']))
HP_MOMENTUM = hp.HParam('momentum', hp.Discrete(np.arange(0.1, 0.9, 0.5).tolist()))
HP_LEARNING_RATE = hp.HParam('lr', hp.Discrete(np.arange(0.1, 0.9, 0.5).tolist()))
HP_DROPOUT1 = hp.HParam('dropout1', hp.Discrete(np.arange(0.1, 0.9, 0.5).tolist()))
HP_DROPOUT2 = hp.HParam('dropout2', hp.Discrete(np.arange(0.1, 0.9, 0.5).tolist()))
#HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
HP_EPOCH = hp.HParam('epoch',hp.Discrete(range(150,250,100)))


METRIC_ACCURACY = 'accuracy'


with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[
        HP_BATCH_SIZE,
        HP_NUM_UNITS1,
        HP_NUM_UNITS2,
        HP_ACTIVATION1,
        HP_ACTIVATION2,
        HP_ACTIVATION3,
        HP_INIT,
        HP_MOMENTUM,
        HP_LEARNING_RATE,
        #HP_OPTIMIZER,
        HP_DROPOUT1,
        HP_DROPOUT2,
        HP_EPOCH
    ],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %% [raw]
# gridParameters=[
#     HP_BATCH_SIZE.__getattribute__("domain").__getattribute__("values"),
#     HP_NUM_UNITS1.__getattribute__("domain").__getattribute__("values"),
#     HP_NUM_UNITS2.__getattribute__("domain").__getattribute__("values"),
#     HP_ACTIVATION1.__getattribute__("domain").__getattribute__("values"),
#     HP_ACTIVATION2.__getattribute__("domain").__getattribute__("values"),
#     HP_ACTIVATION3.__getattribute__("domain").__getattribute__("values"),
#     HP_INIT.__getattribute__("domain").__getattribute__("values"),
#     HP_MOMENTUM.__getattribute__("domain").__getattribute__("values"),
#     HP_LEARNING_RATE.__getattribute__("domain").__getattribute__("values"),
#     HP_DROPOUT1.__getattribute__("domain").__getattribute__("values"),
#     HP_DROPOUT2.__getattribute__("domain").__getattribute__("values"),
#     HP_EPOCH.__getattribute__("domain").__getattribute__("values")
# ]
#
#
# allcombination = list(itertools.product(*gridParameters))
# print(len(allcombination))

# %%
# %load_ext tensorboard

# %%
# reading training and testing data from the csv file
trainDf = pd.read_csv ('data/csv/monks-3Train.csv',header=None).to_numpy()
testDf = pd.read_csv ('data/csv/monks-3Test.csv',header=None).to_numpy()
trainDf = minmax_scale(trainDf, feature_range=(0,1), axis=0)
testDf = minmax_scale(trainDf, feature_range=(0,1), axis=0)

# %%
#Preparing trainDf for training
trainX = trainDf[:, 1:7]
trainY = trainDf[:, 0]
#Preparing testDf for validation
testX = testDf[:, 1:7]
testY = testDf[:, 0]
#trainX = scaler.fit_transform(trainX)
#trainY = scaler.fit_transform(trainY)

# %%
import keras as ks
tensorboard_callback = ks.callbacks.TensorBoard(log_dir="./log",histogram_freq=1,write_graph=True,update_freq=1)

# %%
def create_model(lr=0.1,momentum=0.9,dropout1=0.4,dropout2=0.4,g_hiddeLayerunit1=4,g_hiddeLayerunit2=4,activation1="tanh",activation2="tanh",activation3="sigmoid",init_mode='uniform', g_decay=0.01):
    model = Sequential()
    model.add(Dense(g_hiddeLayerunit1, input_dim=6, kernel_initializer=init_mode, activation=activation1))
    model.add(Dropout(dropout1)),
    model.add(Dense(g_hiddeLayerunit2, kernel_initializer=init_mode, activation=activation2,kernel_regularizer=regularizers.l1(0.01))) # l1 regularization parameter could also be something we can also grid search for.
    model.add(Dropout(dropout2)),
    model.add(Dense(1, activation3))
    sgd = SGD(lr=lr, momentum=momentum, decay=g_decay, nesterov=False,)  # We can add decay to hyper parameter list to get optimum value. 
    model.compile(optimizer=sgd, loss='mean_squared_error',metrics=['accuracy'])
    return model

# %%
def train_test_model(hparams,tensorboard_callback):
    
    
  model = create_model(lr=hparams[HP_LEARNING_RATE],momentum=hparams[HP_MOMENTUM],dropout1=hparams[HP_DROPOUT1],dropout2=hparams[HP_DROPOUT2],g_hiddeLayerunit1=hparams[HP_NUM_UNITS1],g_hiddeLayerunit2=hparams[HP_NUM_UNITS1],activation1=hparams[HP_ACTIVATION1],activation2=hparams[HP_ACTIVATION2],activation3=hparams[HP_ACTIVATION3],init_mode=hparams[HP_INIT], g_decay=0.01)


  model.fit(trainX, trainY, epochs=hparams[HP_EPOCH], callbacks=[tensorboard_callback],verbose=0) # Run with 1 epoch to speed things up for demo purposes
  _, accuracy = model.evaluate(testX, testY)
  return accuracy

def run(run_dir,hparams,tensorboard_callback):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = train_test_model(hparams,tensorboard_callback)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

session_num = 0
class myThread (threading.Thread):
   def __init__(self, threadID,run_dir,hparams,tensorboard_callback):
      threading.Thread.__init__(self)
      self.threadID = threadID
      self.run_dir = run_dir
      self.hparams = hparams
      self.tensorboard_callback=tensorboard_callback
   def run(self):
      print("Starting " + self.name)
      run(self.run_dir,self.hparams,self.tensorboard_callback)
      print("Exiting " + self.name)


for batch_size in HP_BATCH_SIZE.domain.values:
    for num_units1 in HP_NUM_UNITS1.domain.values:
      for num_units2 in HP_NUM_UNITS2.domain.values:
        for activation1 in HP_ACTIVATION1.domain.values:
          for activation2 in HP_ACTIVATION2.domain.values:
            for activation3 in HP_ACTIVATION3.domain.values:
              for init_mode in HP_INIT.domain.values:
                for momentum in HP_MOMENTUM.domain.values:
                  for lr in HP_LEARNING_RATE.domain.values:
                      for dropout_rate1 in HP_DROPOUT1.domain.values:
                        for dropout_rate2 in HP_DROPOUT2.domain.values:
                        #for optimizer in HP_OPTIMIZER.domain.values:
                            for epoch in HP_EPOCH.domain.values:
                              hparams = {
                                  HP_NUM_UNITS1: num_units1,
                                  HP_NUM_UNITS2: num_units2,
                                  HP_ACTIVATION1:activation1,
                                  HP_ACTIVATION2:activation2,
                                  HP_ACTIVATION3:activation3,
                                  HP_INIT:init_mode,
                                  HP_MOMENTUM:momentum,
                                  HP_LEARNING_RATE:lr,
                                  HP_DROPOUT1: dropout_rate1,
                                  HP_DROPOUT2: dropout_rate2,
                                  #HP_OPTIMIZER: optimizer,
                                  HP_EPOCH:epoch,
                                  HP_BATCH_SIZE:batch_size,
                              }
                              run_name = "run-%d" % session_num
                              tensorboard_callback = ks.callbacks.TensorBoard(log_dir="logs/scalar/"+run_name,histogram_freq=1,write_graph=True,update_freq=1)
                              print('--- Starting trial: %s' % run_name)
                              print({h.name: hparams[h] for h in hparams})
                              thread=myThread(session_run,'logs/hparam_tuning/' + run_name, hparams,tensorboard_callback)
                              thread.start()
                              run('logs/hparam_tuning/' + run_name, hparams,tensorboard_callback)
                              session_num += 1





# for batch_size in HP_BATCH_SIZE.domain.values:
#     for num_units1 in HP_NUM_UNITS1.domain.values:
#       for num_units2 in HP_NUM_UNITS2.domain.values:
#         for activation1 in HP_ACTIVATION1.domain.values:
#           for activation2 in HP_ACTIVATION2.domain.values:
#             for activation3 in HP_ACTIVATION3.domain.values:
#               for init_mode in HP_INIT.domain.values:
#                 for momentum in HP_MOMENTUM.domain.values:
#                   for lr in HP_LEARNING_RATE.domain.values:
#                       for dropout_rate1 in HP_DROPOUT1.domain.values:
#                         for dropout_rate2 in HP_DROPOUT2.domain.values:
#                         #for optimizer in HP_OPTIMIZER.domain.values:
#                             for epoch in HP_EPOCH.domain.values:
#                               hparams = {
#                                   HP_NUM_UNITS1: num_units1,
#                                   HP_NUM_UNITS2: num_units2,
#                                   HP_ACTIVATION1:activation1,
#                                   HP_ACTIVATION2:activation2,
#                                   HP_ACTIVATION3:activation3,
#                                   HP_INIT:init_mode,
#                                   HP_MOMENTUM:momentum,
#                                   HP_LEARNING_RATE:lr,
#                                   HP_DROPOUT1: dropout_rate1,
#                                   HP_DROPOUT2: dropout_rate2,
#                                   #HP_OPTIMIZER: optimizer,
#                                   HP_EPOCH:epoch,
#                                   HP_BATCH_SIZE:batch_size,
#                               }
#                               run_name = "run-%d" % session_num
#                               tensorboard_callback = ks.callbacks.TensorBoard(log_dir="logs/scalar/"+run_name,histogram_freq=1,write_graph=True,update_freq=1)
#                               print('--- Starting trial: %s' % run_name)
#                               print({h.name: hparams[h] for h in hparams})
#                               run('logs/hparam_tuning/' + run_name, hparams,tensorboard_callback)
#                               session_num += 1

# %tensorboard --logdir logs
# Out:
# --- Starting trial: run-0
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\branch-env\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0620s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1985 - accuracy: 0.8115
# --- Starting trial: run-1
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5354s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-2
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.5940s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-3
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5461s). Check your callbacks.
# 4/4 [==============================] - 0s 742us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-4
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5560s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-5
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.5460s). Check your callbacks.
# 4/4 [==============================] - 0s 991us/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-6
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5401s). Check your callbacks.
# 4/4 [==============================] - 0s 997us/step - loss: 0.2502 - accuracy: 0.4918
# --- Starting trial: run-7
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.5350s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2471 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.2503 - accuracy: 0.4918
# --- Starting trial: run-8
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5101s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-9
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5350s). Check your callbacks.
# 4/4 [==============================] - 0s 751us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-10
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6260s). Check your callbacks.
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-11
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5830s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-12
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.9220s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-13
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 1.0070s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-14
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.8750s). Check your callbacks.
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.4918
# --- Starting trial: run-15
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5440s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2508 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-16
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4780s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-17
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5710s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-18
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6430s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-19
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4250s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2537 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-20
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5770s). Check your callbacks.
# 4/4 [==============================] - 0s 997us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-21
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4310s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-22
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5510s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-23
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6870s). Check your callbacks.
# 4/4 [==============================] - 0s 749us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-24
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4300s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2062 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1913 - accuracy: 0.8115
# --- Starting trial: run-25
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5110s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-26
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4250s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-27
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6610s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-28
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4220s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-29
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5640s). Check your callbacks.
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-30
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4590s). Check your callbacks.
# 4/4 [==============================] - 0s 742us/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-31
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5030s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-32
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4520s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2106 - accuracy: 0.8361
# --- Starting trial: run-33
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5700s). Check your callbacks.
# 4/4 [==============================] - 0s 749us/step - loss: 0.1534 - accuracy: 0.8525
# --- Starting trial: run-34
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.4440s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-35
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5410s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-36
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.5780s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2502 - accuracy: 0.4918
# --- Starting trial: run-37
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5490s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-38
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4120s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-39
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5880s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.4918
# --- Starting trial: run-40
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5041s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.1482 - accuracy: 0.8115
# --- Starting trial: run-41
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.6090s). Check your callbacks.
# 4/4 [==============================] - 0s 996us/step - loss: 0.2501 - accuracy: 0.4918
# --- Starting trial: run-42
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5530s). Check your callbacks.
# 4/4 [==============================] - 0s 751us/step - loss: 0.1908 - accuracy: 0.8361
# --- Starting trial: run-43
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4080s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2289 - accuracy: 0.7623
# --- Starting trial: run-44
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4970s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-45
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5380s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4918
# --- Starting trial: run-46
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4450s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-47
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5590s). Check your callbacks.
# 4/4 [==============================] - 0s 751us/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-48
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4410s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-49
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4630s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-50
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5811s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2213 - accuracy: 0.7787
# --- Starting trial: run-51
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6390s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-52
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.4261s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-53
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4000s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-54
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6330s). Check your callbacks.
# 4/4 [==============================] - 0s 744us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-55
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.6320s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-56
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6490s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1696 - accuracy: 0.8033
# --- Starting trial: run-57
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4310s). Check your callbacks.
# 4/4 [==============================] - 0s 741us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-58
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4081s). Check your callbacks.
# 4/4 [==============================] - 0s 991us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-59
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4460s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2329 - accuracy: 0.7951
# --- Starting trial: run-60
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6020s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-61
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6240s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2502 - accuracy: 0.4918
# --- Starting trial: run-62
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5630s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2500 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2501 - accuracy: 0.4918
# --- Starting trial: run-63
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'relu', 'activation2': 'tanh', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5900s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2504 - accuracy: 0.4918
# --- Starting trial: run-64
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5630s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-65
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.4900s). Check your callbacks.
# 4/4 [==============================] - 0s 751us/step - loss: 0.4918 - accuracy: 0.5082
# --- Starting trial: run-66
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4920s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1891 - accuracy: 0.8443
# --- Starting trial: run-67
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5000s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-68
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3950s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-69
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4050s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-70
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4000s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-71
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4170s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-72
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.7540s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-73
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6670s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-74
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5240s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.1763 - accuracy: 0.8607
# --- Starting trial: run-75
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4050s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-76
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4120s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.4919 - accuracy: 0.5082
# --- Starting trial: run-77
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-78
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.5690s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2425 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_test_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_begin` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.4918
# --- Starting trial: run-79
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5160s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-80
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.7860s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-81
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.5540s). Check your callbacks.
# 4/4 [==============================] - 0s 751us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-82
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5190s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-83
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6660s). Check your callbacks.
# 4/4 [==============================] - 0s 993us/step - loss: 0.2499 - accuracy: 0.5082
# --- Starting trial: run-84
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4950s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.5082
# --- Starting trial: run-85
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.5330s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-86
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.5590s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-87
# {'num_units1': 4, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4630s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2528 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# ...
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4540s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2504 - accuracy: 0.5082
# --- Starting trial: run-325
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4310s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4921 - accuracy: 0.5082
# --- Starting trial: run-326
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4100s). Check your callbacks.
# 4/4 [==============================] - 0s 994us/step - loss: 0.4921 - accuracy: 0.5082
# --- Starting trial: run-327
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.4930s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2503 - accuracy: 0.5082
# --- Starting trial: run-328
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.7480s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-329
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.7630s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-330
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6780s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.1819 - accuracy: 0.8525
# --- Starting trial: run-331
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3860s). Check your callbacks.
# 4/4 [==============================] - 0s 987us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-332
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4240s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505 - accuracy: 0.5082
# --- Starting trial: run-333
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3861s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5082
# --- Starting trial: run-334
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3871s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2506 - accuracy: 0.5082
# --- Starting trial: run-335
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4040s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2482 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505 - accuracy: 0.4918
# --- Starting trial: run-336
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3980s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-337
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4180s). Check your callbacks.
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-338
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.6920s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-339
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.7541s). Check your callbacks.
# 4/4 [==============================] - 0s 742us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-340
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4500s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5082
# --- Starting trial: run-341
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3950s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5082
# --- Starting trial: run-342
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3730s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5082
# --- Starting trial: run-343
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4200s). Check your callbacks.
# 4/4 [==============================] - 0s 744us/step - loss: 0.2502 - accuracy: 0.5082
# --- Starting trial: run-344
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4130s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-345
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4190s). Check your callbacks.
# 4/4 [==============================] - 0s 992us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-346
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4100s). Check your callbacks.
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2466 - accuracy: 0.6562WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.7951
# --- Starting trial: run-347
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3850s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2500 - accuracy: 0.5082
# --- Starting trial: run-348
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4680s). Check your callbacks.
# 4/4 [==============================] - 0s 749us/step - loss: 0.2506 - accuracy: 0.5082
# --- Starting trial: run-349
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4210s). Check your callbacks.
# 4/4 [==============================] - 0s 750us/step - loss: 0.2503 - accuracy: 0.5082
# --- Starting trial: run-350
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4061s). Check your callbacks.
# 4/4 [==============================] - 0s 999us/step - loss: 0.2504 - accuracy: 0.4918
# --- Starting trial: run-351
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'relu', 'activation3': 'tanh', 'init_mode': 'uniform', 'momentum': 0.6, 'lr': 0.6, 'dropout1': 0.6, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4150s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.5082
# --- Starting trial: run-352
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3881s). Check your callbacks.
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1480 - accuracy: 0.8279
# --- Starting trial: run-353
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.1, 'dropout2': 0.6, 'epoch': 150, 'batch_size': 50}
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.4080s). Check your callbacks.
# 4/4 [==============================] - 0s 751us/step - loss: 0.1628 - accuracy: 0.8607
# --- Starting trial: run-354
# {'num_units1': 8, 'num_units2': 4, 'activation1': 'tanh', 'activation2': 'tanh', 'activation3': 'relu', 'init_mode': 'uniform', 'momentum': 0.1, 'lr': 0.1, 'dropout1': 0.6, 'dropout2': 0.1, 'epoch': 150, 'batch_size': 50}

# %% [raw]
# %%time
# def create_model(lr=0.1,momentum=0.9,g_hiddeLayerunit1=4,g_hiddeLayerunit2=4,activation1="tanh",activation2="tanh",activation3="sigmoid",init_mode='uniform', g_decay=0.01):
#     model = Sequential()
#     model.add(Dense(g_hiddeLayerunit1, input_dim=6, kernel_initializer=init_mode, activation=activation1))
#     model.add(Dropout(0.4)),
#     model.add(Dense(g_hiddeLayerunit2, kernel_initializer=init_mode, activation=activation2,kernel_regularizer=regularizers.l1(0.01))) # l1 regularization parameter could also be something we can also grid search for.
#     model.add(Dropout(0.4)),
#     model.add(Dense(1, activation3))
#     sgd = SGD(lr=lr, momentum=momentum, decay=g_decay, nesterov=False,)  # We can add decay to hyper parameter list to get optimum value.
#     model.compile(optimizer=sgd, loss='mean_squared_error',metrics=['accuracy'])
#     return model
#
#
# class KerasRegressorTB(KerasClassifier):
#
#     def __init__(self, *args, **kwargs):
#         super(KerasClassifier, self).__init__(*args, **kwargs)
#
#     def fit(self, x, y, log_dir=None, **kwargs):
#         cbs = None
#         if log_dir is not None:
#             # Make sure the base log directory exists
#             try:
#                 os.makedirs(log_dir)
#             except OSError:
#                 pass
#             params = self.get_params()
#             conf = ",".join("{}={}".format(k, params[k])
#                             for k in sorted(params))
#             conf_dir_base = os.path.join(log_dir, conf)
#             # Find a new directory to place the logs
#             for i in itertools.count():
#                 try:
#                     conf_dir = "{}_split-{}".format(conf_dir_base, i)
#                     os.makedirs(conf_dir)
#                     break
#                 except OSError:
#                     pass
#             cbs = [ks.callbacks.TensorBoard(log_dir=conf_dir, histogram_freq=0,
#                                write_graph=True, write_images=False)]
#         super(KerasRegressorTB, self).fit(x, y, callbacks=cbs, **kwargs)
#
#
#
# # define the grid search parameters
# batch_size = [10, 20, 40, 60, 80, 100]
# epochs = [10, 50, 100]
# g_hiddeLayerunit1=[4,8,16]
# g_hiddeLayerunit2=[4,8,16]
# g_decay = [0.01] # more estimations can be added
# activation1 = ["relu", "tanh","sigmoid","softmax"]
# activation2 = ["relu", "tanh","sigmoid","softmax"]
# activation3 = ["relu", "tanh","sigmoid","softmax"]
# init_mode = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']
# lr=np.arange(0.1, 0.9, 0.1).tolist()
# momentum=np.arange(0.1, 0.9, 0.1).tolist()
# param_grid = dict(
#     lr=lr,
#    # g_hiddeLayerunit1=g_hiddeLayerunit1,
#    # g_hiddeLayerunit2=g_hiddeLayerunit2,
#    # activation1=activation1,
#    # activation2=activation2,
#    # activation3=activation3,
#    # batch_size=batch_size,
#    # init_mode=init_mode,
#    # g_decay = g_decay,
#    # epochs=epochs
#     )
# model = KerasRegressorTB(build_fn=create_model)
# print("HE")
#
#
# print("HEHE")
# start_time = timer(None) # timing starts from this point for "start_time" variable
# grid = GridSearchCV(estimator=model, param_grid=param_grid,fit_params={'log_dir': './Graph'},n_jobs=1,cv=3,verbose=verbose_level)
#
#
# print("HEHEHE")
# grid_result = grid.fit(trainX, trainY)
# timer(start_time) # timing ends here for "start_time" variable
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# print("Mean\tSTD\tParams")
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs
